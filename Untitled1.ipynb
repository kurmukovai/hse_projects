# %%
import pandas as pd

# %%
df = pd.read_csv('/nmnt/x4-hdd/personal/anvar/cancer-500-paired-kernels.csv', index_col=0)

for _, (suid1, suid2) in df[['SeriesInstanceUID_1', 'SeriesInstanceUID_2']].iterrows():
    img1 = data.image(suid1)
    img2 = data.image(suid2)
    
    lungs1 = model.predict(img1)
    lungs2 = model.predict(img2)
    
    save(lungs1)
    save(lungs2)

# %%
df
# Out:
#                                    SeriesInstanceUID_1  \
# 0    1.2.276.0.7230010.3.1.3.1417964692.10880.15687...
# 1    1.2.276.0.7230010.3.1.3.1417964692.10880.15687...
# 2    1.2.276.0.7230010.3.1.3.1417964692.10880.15687...
# 3    1.2.276.0.7230010.3.1.3.1417964692.10880.15687...
# 4    1.2.276.0.7230010.3.1.3.1417964692.10880.15687...
# ..                                                 ...
# 219  1.2.276.0.7230010.3.1.3.1417964692.10880.15687...
# 220  1.2.276.0.7230010.3.1.3.1417964692.10880.15687...
# 221  1.2.276.0.7230010.3.1.3.1417964692.10880.15687...
# 222  1.2.276.0.7230010.3.1.3.1417964692.10880.15687...
# 223  1.2.276.0.7230010.3.1.3.1417964692.10880.15687...
#
#                                    SeriesInstanceUID_2 ConvolutionalKernel_1  \
# 0    1.2.276.0.7230010.3.1.3.1417964692.10880.15687...                  FC18
# 1    1.2.276.0.7230010.3.1.3.1417964692.10880.15687...                  FC18
# ...

# %%
df2 =
